# %%
# pip install requests
import requests
from bs4 import BeautifulSoup

response = requests.get(
    url="https://www.google.com/search?q=pradeep+chandra+behara+numel+solutions&source=hp&ei=RAZlYcTsM5yRxc8PlvyRuA8&iflsig=ALs-wAMAAAAAYWUUVEXRNvPhHCaJa8DZnQB59btcdVV2&ved=0ahUKEwjEnqCX_MPzAhWcSPEDHRZ-BPcQ4dUDCAc&uact=5&oq=pradeep+chandra+behara+numel+solutions&gs_lcp=&sclient=gws-wiz",
    proxies={"http": "http://UrxFELzNzFo3xf7qJQa8yA:@proxyapi.proxycrawl.com:8000", "https": "http://UrxFELzNzFo3xf7qJQa8yA:@proxyapi.proxycrawl.com:8000"},
    verify=False
)
print('Response Code: ', response.status_code)
data=(response.content)
print(data)
# Out:
# C:\Users\91962\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'proxyapi.proxycrawl.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Response Code:  200
# ...

# %%
data
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en-IN"><head><meta charset="UTF-8"><meta content="origin" name="referrer"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>pradeep chandra behara numel solutions - Google Search</title><script nonce="dSbluNB3NRE7hdgdZRjyew==">(function(){window.google={kEI:\'2RZlYeyJLKjV1sQPstGOqAY\',kEXPI:\'31\',kBL:\'iMdx\'};google.sn=\'web\';google.kHL=\'en-IN\';})();(function(){\nvar f=this||self;var h,k=[];function l(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||h}function m(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}\nfunction n(a,b,c,d,g){var e="";c||-1!==b.search("&ei=")||(e="&ei="+l(d),-1===b.search("&lei=")&&(d=m(d))&&(e+="&lei="+d));d="";!c&&f._cshid&&-1===b.search("&cshid=")&&"slh"!==a&&(d="&cshid="+f._cshid);c=c||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+e
# ...

# %%
soup = BeautifulSoup(data, "lxml")

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
info =[]

containers = soup.find_all('div', {'class': 'g'})
for i in containers:
    info.append(i)

# %%
cont1 =info[0].get_text().strip()

# %%
images = soup.find_all('img', src=True)

print('Number of Images: ', len(images))

for image in images:
    print(image)
# Out:
# Number of Images:  1
# <img alt="Google" height="30" src="/images/branding/googlelogo/2x/googlelogo_color_92x30dp.png" width="92"/>

# %%
image_src = [['src'] for x in images]

image_src = [ for x in image_src if x.endswith('.jpg')]

for image in image_src:
    print(image)

# %%
image_count = 1
for image in image_src:
    with open('image_'+str(image_count)+'.jpg', 'wb') as f:
        res = requests.get(image)
        f.write(res.content)
    image_count = image_count+1
